# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
# !ls
# Out:
# Basic_Python_Pandas.ipynb Work_Common.ipynb         later rename.ipynb
# Others.ipynb              Work_Needed_python.ipynb  tips.txt
# Python_Common.ipynb       classify_by

# %%
tips = pd.read_csv("tips.txt")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# https://seaborn.pydata.org/generated/seaborn.barplot.html
plt.figure(figsize=(20,5))
sns.barplot(x='time',y='total_bill',data=tips,hue="sex")

# %% [markdown]
# sns.barplot / sns.distplot / sns.lineplot / sns.kdeplot / sns.violinplot
# sns.scatterplot / sns.boxplot / sns.heatmap

# %%
# https://seaborn.pydata.org/generated/seaborn.distplot.html
plt.figure(figsize=(20,5))
sns.distplot(tips["total_bill"])
